# %% [markdown]
# # Schedule for Section 3
#
# This is the schedule for the semester. This page will be frequently updated
# based on how we progress and everything is subject to change. Homeworks and
# links to the lecture will be provided here for easy reference to the calendar.
# The assignments refer to the homework **following** a class meeting. So if on
# a particular date it says watch a video, that is for next time! Recording of
# class discussion is always automatically posted after class in NYU Classes.

# %%
from IPython.core.display import HTML, Markdown
import itertools

from datetime import datetime, date, timedelta
import calendar

format = "%A, %B %d, %Y"
short_format = "%a %b %d"
# set the first day of classes
first_day = "Tuesday, September 2, 2025"

# set the last day of class_variables
last_day = "Thursday, December 11, 2025"

# set the recurring days of the weeks
days_of_week = ["Wednesday"]

# add in any additional dates (most commonly legislative day where off cycle class meeting might happen)
# extra_days = {'Tuesday, October 11, 2022': 'Legislative Day (classes meet on Monday schedule)'}
extra_days = {}
extra_days = {datetime.strptime(k, format): v for k, v in extra_days.items()}

# this part runs the script and prints to the terminal the dates
first_day_f = datetime.strptime(first_day, format)
last_day_f = datetime.strptime(last_day, format)

# generator for all the days between two dates
def daterange(start_date, end_date):
    for n in range(int((end_date - start_date).days + 1)):
        yield start_date + timedelta(n)

class_dates = []
for d in daterange(first_day_f, last_day_f):
    if d in extra_days:
        class_dates.append(d)
    if calendar.day_name[d.weekday()] in days_of_week:
        class_dates.append(d)
for d in class_dates:
    print(repr(d))
# Out:
# datetime.datetime(2025, 9, 3, 0, 0)
# datetime.datetime(2025, 9, 10, 0, 0)
# datetime.datetime(2025, 9, 17, 0, 0)
# datetime.datetime(2025, 9, 24, 0, 0)
# datetime.datetime(2025, 10, 1, 0, 0)
# datetime.datetime(2025, 10, 8, 0, 0)
# datetime.datetime(2025, 10, 15, 0, 0)
# datetime.datetime(2025, 10, 22, 0, 0)
# datetime.datetime(2025, 10, 29, 0, 0)
# datetime.datetime(2025, 11, 5, 0, 0)
# datetime.datetime(2025, 11, 12, 0, 0)
# datetime.datetime(2025, 11, 19, 0, 0)
# datetime.datetime(2025, 11, 26, 0, 0)
# datetime.datetime(2025, 12, 3, 0, 0)
# datetime.datetime(2025, 12, 10, 0, 0)

# %%
import markdown

class_dates_info = {
    # Week 1
    datetime(2025, 9, 3, 0, 0): dict(
        Agenda=[
            "Introduction to course",
            "Form groups, set up JupyterHub",
            "[Intro to Cognitive Science ICA](../chapters/00/cogsci-ica.html).",
        ],
        Assignments=[
            "Read/watch [Ch 1: What is Cognitive Science and how do we study it?](../chapters/00/00-cogsci.html)",
            "Read/watch [Ch 2: Why do we have to learn statistics?](../chapters/01/00-whystats.html) by next class.",
            "Read/watch [Ch 3: Introduction to Jupyter](../chapters/02/00-jupyter.html) by next class",
        ]
    ),

    # Week 2
    datetime(2025, 9, 10, 0, 0): dict(
        Agenda=[
            "Discuss Ch 1, 2 and 3",
            "JupyterHub introduction",
            "Start [HW 1](../homeworks/Homework1.html)"
        ],
        Assignments=[
            "Read/watch [Ch 4: Introduction to Python for Psychology Undergraduates](../chapters/03/00-python.html).",
            "Read through [Intro to for-loops](../tips/fortyforloops.html)."
        ]
    ),

    # Week 3
    datetime(2025, 9, 17, 0, 0): dict(
        Agenda=[
            "Group presentation on [Ch 4: Introduction to Python for Psychology Undergraduates](../chapters/03/00-python.html)",
            "Do [Ch 4 ICA: Python](../chapters/03/python-ica.html).",
            "Discuss [Intro to for-loops](../tips/fortyforloops.html)"
        ],
        Assignments=[
            "Read/watch [Ch 5: A brief introduction to research design](../chapters/04/00-researchdesign.html)"
        ]
    ),

    # HOMEWORK 1 DUE
    datetime(2025, 9, 19, 0, 0): dict(
        Agenda="",
        NoClass=True,
        Assignments="<b>Homework 1 Due</b>"
    ),

    # Week 4
    datetime(2025, 9, 24, 0, 0): dict(
        Agenda=[
            "Group presentation on [Ch 5: A brief introduction to research design](../chapters/04/00-researchdesign.html)",
            "Do [Ch 5 ICA: Evaluating research designs](../chapters/04/design-ica.html).",
            "Begin [HW 2: Python for data analysis](../homeworks/hw2/Homework2.html) in class."
        ],
        Assignments="Read/watch [Ch 6: Format and structure of digital data](../chapters/05/00-data.html)."
    ),

    # Week 5
    datetime(2025, 10, 1, 0, 0): dict(
        Agenda=(
            "Group presentation on [Ch 6: Format and structure of digital data](../chapters/05/00-data.html)",
            "Do [Ch 6 ICA: Data and Dataframes](../chapters/05/data-ica-1.html)",
            "Do [HW 2](../homeworks/hw2/Homework2.html) in class.",
        ),
        Assignments="Read/watch [Ch 7: Visualizing data](../chapters/06/00-plots.html)"
    ),

    # Week 6
    datetime(2025, 10, 8, 0, 0): dict(
        Agenda=(
            "Group presentation on [Ch 7: Visualizing data](../chapters/06/00-plots.html)",
            "Do [Ch 7 ICA: Visualizing data](../chapters/06/viz-ica-1.html)",
            "Do [HW 2](../homeworks/hw2/Homework2.html).",
        ),
        Assignments=(
            "Read/watch [Ch 8: Describing data](../chapters/07/00-describingdata.html)",
            "Read/watch [Ch 9: Samples, populations, and sampling](../chapters/08/01-sampling.html)"
        )
    ),

    # HOMEWORK 2 DUE
    datetime(2025, 10, 10, 0, 0): dict(
        Agenda="",
        NoClass=True,
        Assignments="<b>Homework 2 Due</b>"
    ),

    # Week 7
    datetime(2025, 10, 15, 0, 0):  dict(
        Agenda=(
            "Group presentation on [Ch 8: Describing data](../chapters/07/00-describingdata.html)",
            # TODO: Add Ch 8 ICA
            "Group presentation on [Ch 9: Samples, populations, and sampling](../chapters/08/01-sampling.html)",
            "Work on [Ch 9 ICA: Sampling](../chapters/08/sampling-ica.html)",
            "Work on [HW 3: Exploring Data](../homeworks/Homework3.html)."
        ),
        Assignments=(
            "Read/watch [Ch 10: Hypothesis testing](../chapters/09/00-hypothesistesting.html)",
            "Read/watch [Ch 11: Comparing one or two means](../chapters/10/00-ttest.html)"
        )
    ),

    # Week 8
    datetime(2025, 10, 22, 0, 0): dict(
        Agenda=(
            "Group presentation on [Ch 10: Hypothesis Testing](../chapters/09/00-hypothesistesting.html)",
            "Work on [Ch 10 ICA: Hypothesis testing](../chapters/09/hypothesistesting-ica.html)",

            "Group presentation on [Ch 11: Comparing one or two means](../chapters/10/00-ttest.html)",
            "Work on [Ch 11: Differences between means](../chapters/10/ttest-ica.html)",
        ),
        Assignments=[
            "Read/watch [Ch 12: Measuring behavior](../chapters/11/00-inferences-from-behavior.html)"
        ]
    ),
    # HOMEWORK 3 DUE
    datetime(2025, 10, 24, 0, 0): dict(
        Agenda="",
        NoClass=True,
        Assignments="<b>Homework 3 Due</b>"
    ),

    # Week 9
    datetime(2025, 10, 29, 0, 0): dict(
        # Agenda=(
        #     "Group presentation on [Chapter 12: Measuring behavior](../chapters/11/00-inferences-from-behavior.html)",
        #     "Signal Detection Theory lab ([part 1](../labs/LabSDT-Pt1.html), [part 2](../labs/LabSDT-Pt2.html))"
        # ),
        # Assignments=(
        #     "Read/watch [Chapter 13: Research Ethics](../chapters/21/00-ethics-irb.html)",
        #     "Read/watch [Chapter 14: Replication Crisis in Psychology](../chapters/20/replication-crisis-in-psychology.html)"
        # )
    ),

    # Week 10
    datetime(2025, 11, 5, 0, 0): dict(
        # Agenda=(
        #     "Group presentation on [Chapter 13: Research Ethics](../chapters/21/00-ethics-irb.html)",
        #     "Group presentation on [Chapter 14: Replication Crisis in Psychology](../chapters/20/replication-crisis-in-psychology.html)",
        #     "Signal Detection Theory lab<br>([part 1](../labs/LabSDT-Pt1.html), [part 2](../labs/LabSDT-Pt2.html))",
        # ),
        # Assignments="Read/watch [Chapter 15: Linear Regression](../chapters/13/00-linearregression.html)"
    ),

    # Week 11
    datetime(2025, 11, 12, 0, 0): dict(
        # Agenda=(
        #     "Group presentation on [Chapter 15: Linear Regression](../chapters/13/00-linearregression.html)",
        #     "Signal Detection Theory lab<br>([part 1](../labs/LabSDT-Pt1.html), [part 2](../labs/LabSDT-Pt2.html))",
        # ),
        # Assignments=(
        #     "Read [Chapter 17: Linear Mixed Effect Models](../chapters/15/00-mixed-effect.html)"
        # )
    ),

    # Week 12
    datetime(2025, 11, 19, 0, 0): dict(
        # Agenda=(
        #     "Group presentation on [Chapter 17: Linear Mixed Effect Models](../chapters/15/00-mixed-effect.html)",
        #     "Signal Detection Theory lab<br>([part 1](../labs/LabSDT-Pt1.html), [part 2](../labs/LabSDT-Pt2.html))",
        #     "Linear Regression lab<br>([part 1](../labs/LabReg-IntroToRegression.html), [part 2](../labs/LabReg-AdvancedRegression.html), [part 3](../labs/LabReg-MentalRotation.html))",
        # ),
        # Assignments=(
        #     "Read [Chapter 18: Mental Imagery, Mental Simulation, and Mental Rotation](../chapters/16/00-mentalsimulation.html)"
        # )
    ),

    # SDT LAB DUE
    # datetime(2025, 11, 21, 0, 0): dict(
    #     Agenda="",
    #     NoClass=True,
    #     Assignments="<b>Signal Detection Theory lab due</b>"
    # ),

    # Week 13
    datetime(2025, 11, 26, 0, 0): dict(
        Agenda="<b>No class (Legislative Friday)</b>",
        Assignments="",
        NoClass=True,
        Warning=True
    ),

    # Week 14
    datetime(2025, 12, 3, 0, 0): dict(
        # Agenda=(
        #     "Group presentation on [Chapter 18: Mental Imagery, Mental Simulation, and Mental Rotation](../chapters/16/00-mentalsimulation.html)",
        #     "Linear Regression lab<br>([part 1](../labs/LabReg-IntroToRegression.html), [part 2](../labs/LabReg-AdvancedRegression.html), [part 3](../labs/LabReg-MentalRotation.html))",
        #     "<b>EXTRA CREDIT:</b> Functional Magnetic Resonance Imaging lab<br>([part 1](../labs/LabReg-MRI-Pt1.html), [part 2](../labs/LabReg-MRI-Pt2.html))"
        # ),
        # Assignments=(
        #     "Read/watch [Chapter 21: What's Next?](../chapters/24/00-what-next.html)",
        #     "<b>OPTIONAL</b>: Read [Chapter 19: Functional Magnetic Resonance Imaging](../chapters/17/00-mri.html)"
        # )
    ),

    # Week 15
    datetime(2025, 12, 10, 0, 0): dict(
        # Agenda=(
        #     "Final Discussion"
        #     "Linear Regression lab<br>([part 1](../labs/LabReg-IntroToRegression.html), [part 2](../labs/LabReg-AdvancedRegression.html), [part 3](../labs/LabReg-MentalRotation.html))",
        #     "<b>EXTRA CREDIT:</b> Group presentation on [Chapter 19: Functional Magnetic Resonance Imaging](../chapters/17/00-mri.html)",
        #     "<b>EXTRA CREDIT:</b> Functional Magnetic Resonance Imaging lab<br>([part 1](../labs/LabReg-MRI-Pt1.html), [part 2](../labs/LabReg-MRI-Pt2.html))"
        # ),
        # Assignments=()
    ),

    # Linear Regression LAB DUE
    # datetime(2025, 12, 12, 0, 0): dict(
    #     Agenda="",
    #     NoClass=True,
    #     Assignments="<b>Linear regression lab due</b>"
    # ),

    # FMRI Lab stuff
    # datetime(2025, 4, 23, 0, 0): dict(
    #     # Agenda="Functional Magnetic Resonance Imaging lab<br>([part 1](../labs/Lab-MRI-Pt1.html), [part 2](../labs/Lab-MRI-Pt2.html))",
    #     # Assignments="Read [Chapter 17: Linear Mixed Effect Models](../chapters/14/00-lmm.html)"
    #     # Assignments="Read [Chapter 16: Logistic Regression](../chapters/16/00-logisticregression.html)"
    # ),
    # datetime(2025, 4, 28, 0, 0): dict(
    #     # Agenda="Functional Magnetic Resonance Imaging lab<br>([part 1](../labs/Lab-MRI-Pt1.html), [part 2](../labs/Lab-MRI-Pt2.html))",
    #     # Assignments="TBD"
    # ),
    # datetime(2025, 4, 30, 0, 0): dict(
    #     # Agenda="Functional Magnetic Resonance Imaging lab<br>([part 1](../labs/Lab-MRI-Pt1.html), [part 2](../labs/Lab-MRI-Pt2.html))",
    #     # Assignments="Read/watch [Chapter 20: Writing and Presenting](../chapters/19/00-writingandpresenting.html)"
    # ),
    # datetime(2025, 5, 5, 0, 0): dict(
    #     # Agenda="Functional Magnetic Resonance Imaging lab<br>([part 1](../labs/Lab-MRI-Pt1.html), [part 2](../labs/Lab-MRI-Pt2.html))",
    #     # Assignments="Read/watch [Chapter 21: What's Next?](../chapters/24/00-what-next.html)"
    # ),
 }

# %%
WARNING = '<br><span class="badge rounded-pill bg-warning text-dark">Warning</span>'
NOCLASS = '<br><span class="badge rounded-pill bg-danger text-dark">No class</span>'
table_rows = []
for d in class_dates_info:
    agenda = class_dates_info[d].get("Agenda", "TBD")
    if isinstance(agenda, (tuple, list)):
        agenda = "<br>".join(agenda)
    assignments = class_dates_info[d].get("Assignments", "TBD")
    if isinstance(assignments, (tuple, list)):
        assignments = "<br>".join(assignments)
    table_rows.append(
     f'''<tr class="align-top">
        <th scope="row" class="text-left align-top">
        {datetime.strftime(d, "%a, %b %d")}
        {WARNING if class_dates_info[d].get("Warning", False) else ""}
        {NOCLASS if class_dates_info[d].get("NoClass", False) else ""}
        </th>
        <td class="text-left align-top"> 
        {markdown.markdown(agenda)}
        </td>
        <td class="text-left align-top"> 
        {markdown.markdown(assignments)}
        </td>
     </tr>'''
    )
table_rows = '\n'.join(table_rows)
table_html = f"""
<table class="table table-striped text-left">
  <thead class="thead-dark">
    <tr>
      <th scope="col" class="text-left">Date</th>
      <th scope="col" class="text-left" width="50%">Agenda</th>
      <th scope="col" class="text-left" width="35%">Assignments</th>
    </tr>
  </thead>
  <tbody>
  {table_rows}
  </tbody>
</table>
"""

# %%
HTML(table_html)
# Out:
# <table class="table table-striped text-left">
#   <thead class="thead-dark">
#     <tr>
#       <th scope="col" class="text-left">Date</th>
#       <th scope="col" class="text-left" width="50%">Agenda</th>
#       <th scope="col" class="text-left" width="35%">Assignments</th>
#     </tr>
#   </thead>
#   <tbody>
#   <tr class="align-top">
#         <th scope="row" class="text-left align-top">
#         Wed, Sep 03
#
#
#         </th>
#         <td class="text-left align-top">
#         <p>Introduction to course<br>Form groups, set up JupyterHub<br><a href="../chapters/00/cogsci-ica.html">Intro to Cognitive Science ICA</a>.</p>
#         </td>
#         <td class="text-left align-top">
# ...
