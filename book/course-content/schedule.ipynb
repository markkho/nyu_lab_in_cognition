# %% [markdown]
# # Schedule
#
# This is the schedule for the semester. This page will be frequently updated
# based on how we progress and everything is subject to change. Homeworks and
# links to the lecture will be provided here for easy reference to the calendar.
# The assignments refer to the homework **following** a class meeting. So if on
# a particular date it says watch a video, that is for next time! Recording of
# class discussion is always automatically posted after class in NYU Classes.

# %%
from IPython.core.display import HTML, Markdown
import itertools

from datetime import datetime, date, timedelta
import calendar

format = "%A, %B %d, %Y"
short_format = "%a %b %d"
# 1. set the first day of classes
first_day = "Wednesday, January 22, 2025"

# 2. set the last day of class_variables
last_day = "Monday, May 5, 2025"

# 3. set the recurring days of the weeks
days_of_week = ["Monday", "Wednesday"]

# 4. add in the date of the final exam
final_exam_day = None

# 4. list any exceptions for like holidays and the like
holidays = {
    "Monday, February 17, 2025": "Presidents' Day",
    "Monday, March 24, 2025": "Spring Break",
    "Wednesday, March 26, 2025": "Spring Break",
}
holidays = {datetime.strptime(k, format): v for k, v in holidays.items()}

# 5. add in any additional dates (most commonly legislative day where off cycle class meeting might happen)
# extra_days = {'Tuesday, October 11, 2022': 'Legislative Day (classes meet on Monday schedule)'}
extra_days = {
    "Tuesday, February 18, 2025": "Legislative Day (classes meet on Monday schedule)"
}
extra_days = {datetime.strptime(k, format): v for k, v in extra_days.items()}

# this part runs the script and prints to the terminal the dates
first_day_f = datetime.strptime(first_day, format)
last_day_f = datetime.strptime(last_day, format)

# generator for all the days between two dates
def daterange(start_date, end_date):
    for n in range(int((end_date - start_date).days + 1)):
        yield start_date + timedelta(n)

class_dates_info = {}
for d in daterange(first_day_f, last_day_f):
    if d in extra_days:
        class_dates_info[d] = dict(
            Note=extra_days[d]
        )
    if calendar.day_name[d.weekday()] in days_of_week:
        class_dates_info[d] = dict()

# %%
table_rows = []
for d in class_dates_info:
    table_rows.append(
     f'''<tr class="align-top">
        <th scope="row" class="text-left align-top">{datetime.strftime(d, "%a, %b %d")}</th>
        <td class="text-left align-top"> TBD </td>
        <td class="text-left align-top"> TBD </td>
     </tr>'''
    )
table_rows = '\n'.join(table_rows)
table_html = f"""
<table class="table table-striped text-left">
  <thead class="thead-dark">
    <tr>
      <th scope="col" class="text-left">Date</th>
      <th scope="col" class="text-left" width="50%">Agenda</th>
      <th scope="col" class="text-left" width="35%">Assignments</th>
    </tr>
  </thead>
  <tbody>
  {table_rows}
  </tbody>
</table>
"""
print(table_html)
# Out:
# <table class="table table-striped text-left">
#   <thead class="thead-dark">
#     <tr>
#       <th scope="col" class="text-left">Date</th>
#       <th scope="col" class="text-left" width="50%">Agenda</th>
#       <th scope="col" class="text-left" width="35%">Assignments</th>
#     </tr>
#   </thead>
#   <tbody>
#   <tr class="align-top">
#         <th scope="row" class="text-left align-top">Wed, Jan 22</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Mon, Jan 27</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Wed, Jan 29</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
# ...

# %% [markdown]
# <table class="table table-striped text-left">
#   <thead class="thead-dark">
#     <tr>
#       <th scope="col" class="text-left">Date</th>
#       <th scope="col" class="text-left" width="50%">Agenda</th>
#       <th scope="col" class="text-left" width="35%">Assignments</th>
#     </tr>
#   </thead>
#   <tbody>
#   <tr class="align-top">
#         <th scope="row" class="text-left align-top">Wed, Jan 22</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Mon, Jan 27</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Wed, Jan 29</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Mon, Feb 03</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Wed, Feb 05</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Mon, Feb 10</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Wed, Feb 12</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Mon, Feb 17<br><span class="badge rounded-pill bg-warning text-dark">Warning</span></th>
#         <td class="text-left align-top"> <b>No class - Presidents' Day</b></td>
#         <td class="text-left align-top"> </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Tue, Feb 18<br><span class="badge rounded-pill bg-warning text-dark">Warning</span></th>
#         <td class="text-left align-top"> <b>Classes meet on Monday schedule</b> </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Wed, Feb 19</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Mon, Feb 24</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Wed, Feb 26</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Mon, Mar 03</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Wed, Mar 05</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Mon, Mar 10</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Wed, Mar 12</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Mon, Mar 17</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Wed, Mar 19</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Mon, Mar 24<br><span class="badge rounded-pill bg-warning text-dark">Warning</span></th>
#         <td class="text-left align-top"> <b> No class - Spring Break </b> </td>
#         <td class="text-left align-top"> </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Wed, Mar 26<br><span class="badge rounded-pill bg-warning text-dark">Warning</span></th>
#         <td class="text-left align-top"> <b> No class - Spring Break </b> </td>
#         <td class="text-left align-top"> </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Mon, Mar 31</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Wed, Apr 02</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Mon, Apr 07</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Wed, Apr 09</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Mon, Apr 14</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Wed, Apr 16</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Mon, Apr 21</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Wed, Apr 23</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Mon, Apr 28</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Wed, Apr 30</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
# <tr class="align-top">
#         <th scope="row" class="text-left align-top">Mon, May 05</th>
#         <td class="text-left align-top"> TBD </td>
#         <td class="text-left align-top"> TBD </td>
#      </tr>
#   </tbody>
# </table>
